# %%
print("Hello, World!")
print("This is a sample output.")
print("Feel free to modify this code as needed.")
# Out:
# Hello, World!
# This is a sample output.
# Feel free to modify this code as needed.
